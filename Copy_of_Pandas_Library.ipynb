# %% [markdown]
# <a href="https://colab.research.google.com/github/521sai/Pandas_Library/blob/main/Copy_of_Pandas_Library.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
dataset=pd.read_csv('/content/sample_data/annex1.csv')
dataset
# Out:
#            Item Code                                     Item Name  \
# 0    102900005115168                              Niushou Shengcai
# 1    102900005115199                             Sichuan Red Cedar
# 2    102900005115625                         Local Xiaomao Cabbage
# 3    102900005115748                                  White Caitai
# 4    102900005115762                                      Amaranth
# ..               ...                                           ...
# 246  106958851400125                    Haixian Mushroom (Bag) (4)
# 247  106971533450003                      Haixian Mushroom (Bunch)
# 248  106971533455008                    Haixian Mushroom (Bag) (3)
# 249  106973223300667  Chinese Caterpillar Fungus Flowers (Box) (2)
# 250  106973990980123                 Hfyg Haixian Mushroom (Bunch)
#
#      Category Code           Category Name
# 0       1011010101  Flower/Leaf Vegetables
# 1       1011010101  Flower/Leaf Vegetables
# ...

# %% [markdown]
# #Head

# %%
dataset.head()
# Out:
#          Item Code              Item Name  Category Code  \
# 0  102900005115168       Niushou Shengcai     1011010101
# 1  102900005115199      Sichuan Red Cedar     1011010101
# 2  102900005115625  Local Xiaomao Cabbage     1011010101
# 3  102900005115748           White Caitai     1011010101
# 4  102900005115762               Amaranth     1011010101
#
#             Category Name
# 0  Flower/Leaf Vegetables
# 1  Flower/Leaf Vegetables
# 2  Flower/Leaf Vegetables
# 3  Flower/Leaf Vegetables
# 4  Flower/Leaf Vegetables

# %% [markdown]
# #Tail

# %%
dataset.tail()
# Out:
#            Item Code                                     Item Name  \
# 246  106958851400125                    Haixian Mushroom (Bag) (4)
# 247  106971533450003                      Haixian Mushroom (Bunch)
# 248  106971533455008                    Haixian Mushroom (Bag) (3)
# 249  106973223300667  Chinese Caterpillar Fungus Flowers (Box) (2)
# 250  106973990980123                 Hfyg Haixian Mushroom (Bunch)
#
#      Category Code    Category Name
# 246     1011010801  Edible Mushroom
# 247     1011010801  Edible Mushroom
# 248     1011010801  Edible Mushroom
# 249     1011010801  Edible Mushroom
# 250     1011010801  Edible Mushroom

# %% [markdown]
# #Sample
# it returns the random row with columns

# %%
dataset.sample()
# Out:
#            Item Code                  Item Name  Category Code  \
# 240  106949711300167  Needle Mushroom (Bag) (2)     1011010801
#
#        Category Name
# 240  Edible Mushroom

# %% [markdown]
# #info
# describe the column types

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 251 entries, 0 to 250
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Item Code      251 non-null    int64
#  1   Item Name      251 non-null    object
#  2   Category Code  251 non-null    int64
#  3   Category Name  251 non-null    object
# dtypes: int64(2), object(2)
# memory usage: 8.0+ KB

# %% [markdown]
# #Datatype
# of columns

# %%
dataset.dtypes
# Out:
# Item Code         int64
# Item Name        object
# Category Code     int64
# Category Name    object
# dtype: object

# %% [markdown]
# #Shape
# it returns the number of columns and rows

# %%
dataset.shape
# Out:
# (251, 4)

# %% [markdown]
# #Size

# %%
dataset.size
# Out:
# 1004

# %% [markdown]
# #ndim
# returns the 2 if DataFrame or 1 if Series

# %%
dataset.ndim
# Out:
# 2

# %% [markdown]
# #describe
# it returns the mean,median,standard deviation,etc..
# it is perform only integer type columns

# %%
dataset.describe()
# Out:
#           Item Code  Category Code
# count  2.510000e+02   2.510000e+02
# mean   1.031908e+14   1.011010e+09
# std    1.048400e+12   2.915469e+02
# min    1.029000e+14   1.011010e+09
# 25%    1.029000e+14   1.011010e+09
# 50%    1.029000e+14   1.011011e+09
# 75%    1.029000e+14   1.011011e+09
# max    1.069740e+14   1.011011e+09

# %% [markdown]
# #unique
# it returns the unique data in the columns

# %%
dataset['Category Name'].unique()
# Out:
# array(['Flower/Leaf\xa0Vegetables', 'Cabbage',
#        'Aquatic Tuberous Vegetables', 'Solanum', 'Capsicum',
#        'Edible Mushroom'], dtype=object)

# %% [markdown]
# #nunique
# number of unique values in the column

# %%
dataset['Category Name'].nunique()
# Out:
# 6

# %% [markdown]
# #isnull
# it returns True when data is missing
# it returns the False when data is not missing

# %%
dataset.isnull()
# Out:
#      Item Code  Item Name  Category Code  Category Name
# 0        False      False          False          False
# 1        False      False          False          False
# 2        False      False          False          False
# 3        False      False          False          False
# 4        False      False          False          False
# ..         ...        ...            ...            ...
# 246      False      False          False          False
# 247      False      False          False          False
# 248      False      False          False          False
# 249      False      False          False          False
# 250      False      False          False          False
#
# [251 rows x 4 columns]

# %% [markdown]
# #isna

# %%
dataset.isna()
# Out:
#      Item Code  Item Name  Category Code  Category Name
# 0        False      False          False          False
# 1        False      False          False          False
# 2        False      False          False          False
# 3        False      False          False          False
# 4        False      False          False          False
# ..         ...        ...            ...            ...
# 246      False      False          False          False
# 247      False      False          False          False
# 248      False      False          False          False
# 249      False      False          False          False
# 250      False      False          False          False
#
# [251 rows x 4 columns]

# %% [markdown]
# #fillna
# filling the missing values

# %%
dataset.fillna(2)
# Out:
#            Item Code                                     Item Name  \
# 0    102900005115168                              Niushou Shengcai
# 1    102900005115199                             Sichuan Red Cedar
# 2    102900005115625                         Local Xiaomao Cabbage
# 3    102900005115748                                  White Caitai
# 4    102900005115762                                      Amaranth
# ..               ...                                           ...
# 246  106958851400125                    Haixian Mushroom (Bag) (4)
# 247  106971533450003                      Haixian Mushroom (Bunch)
# 248  106971533455008                    Haixian Mushroom (Bag) (3)
# 249  106973223300667  Chinese Caterpillar Fungus Flowers (Box) (2)
# 250  106973990980123                 Hfyg Haixian Mushroom (Bunch)
#
#      Category Code           Category Name
# 0       1011010101  Flower/Leaf Vegetables
# 1       1011010101  Flower/Leaf Vegetables
# ...

# %% [markdown]
# #clip
# it returns the index information

# %%
dataset.clip()
# Out:
#            Item Code                                     Item Name  \
# 0    102900005115168                              Niushou Shengcai
# 1    102900005115199                             Sichuan Red Cedar
# 2    102900005115625                         Local Xiaomao Cabbage
# 3    102900005115748                                  White Caitai
# 4    102900005115762                                      Amaranth
# ..               ...                                           ...
# 246  106958851400125                    Haixian Mushroom (Bag) (4)
# 247  106971533450003                      Haixian Mushroom (Bunch)
# 248  106971533455008                    Haixian Mushroom (Bag) (3)
# 249  106973223300667  Chinese Caterpillar Fungus Flowers (Box) (2)
# 250  106973990980123                 Hfyg Haixian Mushroom (Bunch)
#
#      Category Code           Category Name
# 0       1011010101  Flower/Leaf Vegetables
# 1       1011010101  Flower/Leaf Vegetables
# ...

# %% [markdown]
# #columns
# returns the columns names

# %%
dataset.columns
# Out:
# Index(['Item Code', 'Item Name', 'Category Code', 'Category Name'], dtype='object')

# %% [markdown]
# #sort_values
# returns the ascending and descending order of columns

# %%
dataset.sort_values('Category Name')
# Out:
#            Item Code                    Item Name  Category Code  \
# 105  102900005116042                   Lotus Root     1011010402
# 120  102900011035511           Net Lotus Root (3)     1011010402
# 119  102900011034569    Honghu Lotus (Lotus Root)     1011010402
# 118  102900011032732               High Melon (2)     1011010402
# 116  102900011024010  Fresh Lotus Root Zone (Bag)     1011010402
# ..               ...                          ...            ...
# 129  102900011022764                 Changxianqie     1011010501
# 130  102900011033975           Green Eggplant (2)     1011010501
# 131  102900011033982                 Eggplant (1)     1011010501
# 133  102900051000463           Round Eggplant (2)     1011010501
# 125  102900005116509           Green Eggplant (1)     1011010501
#
#                    Category Name
# 105  Aquatic Tuberous Vegetables
# 120  Aquatic Tuberous Vegetables
# 119  Aquatic Tuberous Vegetables
# 118  Aquatic Tuberous Vegetables
# ...

# %% [markdown]
# #Value_counts
# count the unique values

# %%
dataset.value_counts('Item Code')
# Out:
# Item Code
# 102900005115168    1
# 102900011032480    1
# 102900011032114    1
# 102900011032145    1
# 102900011032176    1
#                   ..
# 102900011010563    1
# 102900011010891    1
# 102900011011058    1
# 102900011011546    1
# 106973990980123    1
# Length: 251, dtype: int64

# %% [markdown]
# #nlargest
# returns the n largest values form dataset

# %%
dataset.nlargest(2,'Category Code')
# Out:
#            Item Code                 Item Name  Category Code    Category Name
# 179  102900005115250  Xixia Black Mushroom (1)     1011010801  Edible Mushroom
# 180  102900005116530        Xixia Mushroom (1)     1011010801  Edible Mushroom

# %% [markdown]
# #nsmallest
# returns the smallest values of columns

# %%
dataset.nsmallest(4,'Category Code')
# Out:
#          Item Code              Item Name  Category Code  \
# 0  102900005115168       Niushou Shengcai     1011010101
# 1  102900005115199      Sichuan Red Cedar     1011010101
# 2  102900005115625  Local Xiaomao Cabbage     1011010101
# 3  102900005115748           White Caitai     1011010101
#
#             Category Name
# 0  Flower/Leaf Vegetables
# 1  Flower/Leaf Vegetables
# 2  Flower/Leaf Vegetables
# 3  Flower/Leaf Vegetables

# %% [markdown]
# #copy
# copy the dataframe into another dataset

# %%
dataset.copy('df')
# Out:
#            Item Code                                     Item Name  \
# 0    102900005115168                              Niushou Shengcai
# 1    102900005115199                             Sichuan Red Cedar
# 2    102900005115625                         Local Xiaomao Cabbage
# 3    102900005115748                                  White Caitai
# 4    102900005115762                                      Amaranth
# ..               ...                                           ...
# 246  106958851400125                    Haixian Mushroom (Bag) (4)
# 247  106971533450003                      Haixian Mushroom (Bunch)
# 248  106971533455008                    Haixian Mushroom (Bag) (3)
# 249  106973223300667  Chinese Caterpillar Fungus Flowers (Box) (2)
# 250  106973990980123                 Hfyg Haixian Mushroom (Bunch)
#
#      Category Code           Category Name
# 0       1011010101  Flower/Leaf Vegetables
# 1       1011010101  Flower/Leaf Vegetables
# ...

# %% [markdown]
# #loc
# used to access grp of rows and columns

# %%
dataset.loc[12,'Category Name']
# Out:
# 'Flower/Leaf\xa0Vegetables'

# %%
dataset.loc[1:4,['Item Name','Category Name']]
# Out:
#                Item Name           Category Name
# 1      Sichuan Red Cedar  Flower/Leaf Vegetables
# 2  Local Xiaomao Cabbage  Flower/Leaf Vegetables
# 3           White Caitai  Flower/Leaf Vegetables
# 4               Amaranth  Flower/Leaf Vegetables

# %% [markdown]
# #iloc
# used to access the specified rows

# %%
dataset.iloc[2:10:2]
# Out:
#          Item Code              Item Name  Category Code  \
# 2  102900005115625  Local Xiaomao Cabbage     1011010101
# 4  102900005115762               Amaranth     1011010101
# 6  102900005115786               Zhuyecai     1011010101
# 8  102900005115816             Nanguajian     1011010101
#
#             Category Name
# 2  Flower/Leaf Vegetables
# 4  Flower/Leaf Vegetables
# 6  Flower/Leaf Vegetables
# 8  Flower/Leaf Vegetables

# %% [markdown]
# #rename
# used for rename the columns,rows and index

# %%
dataset.rename(columns={'Item Code':'Item Codes'})
# Out:
#           Item Codes                                     Item Name  \
# 0    102900005115168                              Niushou Shengcai
# 1    102900005115199                             Sichuan Red Cedar
# 2    102900005115625                         Local Xiaomao Cabbage
# 3    102900005115748                                  White Caitai
# 4    102900005115762                                      Amaranth
# ..               ...                                           ...
# 246  106958851400125                    Haixian Mushroom (Bag) (4)
# 247  106971533450003                      Haixian Mushroom (Bunch)
# 248  106971533455008                    Haixian Mushroom (Bag) (3)
# 249  106973223300667  Chinese Caterpillar Fungus Flowers (Box) (2)
# 250  106973990980123                 Hfyg Haixian Mushroom (Bunch)
#
#      Category Code           Category Name
# 0       1011010101  Flower/Leaf Vegetables
# 1       1011010101  Flower/Leaf Vegetables
# ...

# %% [markdown]
# #where

# %%
filter=dataset["Category Name"]=="Edible Mushroom"

# %%
dataset.where(filter,inplace=False)
# Out:
#         Item Code                                     Item Name  \
# 0             NaN                                           NaN
# 1             NaN                                           NaN
# 2             NaN                                           NaN
# 3             NaN                                           NaN
# 4             NaN                                           NaN
# ..            ...                                           ...
# 246  1.069589e+14                    Haixian Mushroom (Bag) (4)
# 247  1.069715e+14                      Haixian Mushroom (Bunch)
# 248  1.069715e+14                    Haixian Mushroom (Bag) (3)
# 249  1.069732e+14  Chinese Caterpillar Fungus Flowers (Box) (2)
# 250  1.069740e+14                 Hfyg Haixian Mushroom (Bunch)
#
#      Category Code    Category Name
# 0              NaN              NaN
# 1              NaN              NaN
# 2              NaN              NaN
# 3              NaN              NaN
# ...

# %% [markdown]
# #drop
# drop the rows/columns from dataframe

# %%
dataset.drop(["Item Code"],axis=1)
# Out:
#                                         Item Name  Category Code  \
# 0                                Niushou Shengcai     1011010101
# 1                               Sichuan Red Cedar     1011010101
# 2                           Local Xiaomao Cabbage     1011010101
# 3                                    White Caitai     1011010101
# 4                                        Amaranth     1011010101
# ..                                            ...            ...
# 246                    Haixian Mushroom (Bag) (4)     1011010801
# 247                      Haixian Mushroom (Bunch)     1011010801
# 248                    Haixian Mushroom (Bag) (3)     1011010801
# 249  Chinese Caterpillar Fungus Flowers (Box) (2)     1011010801
# 250                 Hfyg Haixian Mushroom (Bunch)     1011010801
#
#               Category Name
# 0    Flower/Leaf Vegetables
# 1    Flower/Leaf Vegetables
# 2    Flower/Leaf Vegetables
# 3    Flower/Leaf Vegetables
# 4    Flower/Leaf Vegetables
# ...

# %% [markdown]
# #groupby

# %%
dataset.groupby('Category Name')

# %% [markdown]
# #correlation method

# %%
dataset.corr()
# Out:
# <ipython-input-65-c187c74d1e71>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   dataset.corr()
#                Item Code  Category Code
# Item Code       1.000000       0.294345
# Category Code   0.294345       1.000000

# %% [markdown]
# #insert
# insert the new columns with values

# %%
dataset.insert(4,'Categorys',"True")

# %%
dataset.head()
# Out:
#          Item Code              Item Name  Category Code  \
# 0  102900005115168       Niushou Shengcai     1011010101
# 1  102900005115199      Sichuan Red Cedar     1011010101
# 2  102900005115625  Local Xiaomao Cabbage     1011010101
# 3  102900005115748           White Caitai     1011010101
# 4  102900005115762               Amaranth     1011010101
#
#             Category Name Categorys    sai
# 0  Flower/Leaf Vegetables      True  hello
# 1  Flower/Leaf Vegetables      True  hello
# 2  Flower/Leaf Vegetables      True  hello
# 3  Flower/Leaf Vegetables      True  hello
# 4  Flower/Leaf Vegetables      True  hello

# %% [markdown]
# #sum
# adding all values

# %%
dataset.sum()
# Out:
# Item Code                                        25900897091173604
# Item Name        Niushou ShengcaiSichuan Red CedarLocal Xiaomao...
# Category Code                                         253763614105
# Category Name    Flower/Leaf VegetablesFlower/Leaf VegetablesFl...
# Categorys        TrueTrueTrueTrueTrueTrueTrueTrueTrueTrueTrueTr...
# sai              hellohellohellohellohellohellohellohellohelloh...
# dtype: object

# %%
dataset.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 246    False
# 247    False
# 248    False
# 249    False
# 250    False
# Length: 251, dtype: bool
