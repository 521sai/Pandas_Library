# %% [markdown]
# <a href="https://colab.research.google.com/github/521sai/Pandas_Library/blob/main/Pandas_datacombining.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df1=pd.DataFrame({'A':['A1','A2','A3','A4'],
                  'B':['B1','B2','B3','B4'],
                  'C':['C1','C2','C3','C4'],
                  'D':['D1','D2','D3','D4']})
df1
# Out:
#     A   B   C   D
# 0  A1  B1  C1  D1
# 1  A2  B2  C2  D2
# 2  A3  B3  C3  D3
# 3  A4  B4  C4  D4

# %%
df2=pd.DataFrame({'A':['A5','A6','A7','A8'],
                  'B':['B5','B6','B7','B8'],
                  'C':['C5','C6','C7','C8'],
                  'D':['D5','D6','D7','D8']})
df2
# Out:
#     A   B   C   D
# 0  A5  B5  C5  D5
# 1  A6  B6  C6  D6
# 2  A7  B7  C7  D7
# 3  A8  B8  C8  D8

# %%
df3=pd.DataFrame({'A':['A9','A10','A11','A12'],
                  'B':['B9','B10','B11','B12'],
                  'C':['C9','C10','C11','C12'],
                  'D':['D9','D10','D11','D12']})
df3
# Out:
#      A    B    C    D
# 0   A9   B9   C9   D9
# 1  A10  B10  C10  D10
# 2  A11  B11  C11  D11
# 3  A12  B12  C12  D12

# %%
pd.concat([df1 ,df2 ,df3] , axis=1)
# Out:
#     A   B   C   D   A   B   C   D    A    B    C    D
# 0  A1  B1  C1  D1  A5  B5  C5  D5   A9   B9   C9   D9
# 1  A2  B2  C2  D2  A6  B6  C6  D6  A10  B10  C10  D10
# 2  A3  B3  C3  D3  A7  B7  C7  D7  A11  B11  C11  D11
# 3  A4  B4  C4  D4  A8  B8  C8  D8  A12  B12  C12  D12

# %%
df1.head(2)
# Out:
#     A   B   C   D
# 0  A1  B1  C1  D1
# 1  A2  B2  C2  D2

# %%
df2.tail(2)
# Out:
#     A   B   C   D
# 2  A7  B7  C7  D7
# 3  A8  B8  C8  D8

# %%
df=pd.DataFrame({'col1':['a','b','c','d'],
              'col2':[55,66,77,55],
              'col3':[1,2,3,4]})

# %%
df['col2'].unique()
# Out:
# array([55, 66, 77])

# %%
df['col2'].nunique()
# Out:
# 3

# %%
df['col2'].value_counts()
# Out:
# 55    2
# 66    1
# 77    1
# Name: col2, dtype: int64

# %% [markdown]
# #Applying Functions

# %%
def square(x):
  return x*x

# %%
df['col3']=df['col3'].apply(square)

# %%
df
# Out:
#   col1  col2  col3
# 0    a    55     1
# 1    b    66     4
# 2    c    77     9
# 3    d    55    16

# %%
df['col1'].apply(len)#length of column1
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# Name: col1, dtype: int64

# %%
df.columns
# Out:
# Index(['col1', 'col2', 'col3'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
df
# Out:
#   col1  col2  col3
# 0    a    55     1
# 1    b    66     4
# 2    c    77     9
# 3    d    55    16

# %%
df.describe()
# Out:
#             col2       col3
# count   4.000000   4.000000
# mean   63.250000   7.500000
# std    10.531698   6.557439
# min    55.000000   1.000000
# 25%    55.000000   3.250000
# 50%    60.500000   6.500000
# 75%    68.750000  10.750000
# max    77.000000  16.000000
